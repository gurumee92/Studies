# %% [markdown]
# # LLMs and Chat Models

# %%
# from langchain.llms.openai import OpenAI
from langchain.chat_models import ChatOpenAI

# llm = OpenAI(model_name="gpt-3.5-turbo")
chat = ChatOpenAI()

# a = llm.predict("행성은 몇 개 있니?")
b = chat.predict("행성은 몇 개 있니?")
b
# Out:
# ('태양계에는 8개의 행성이 있습니다. 이들은 수성, 금성, 지구, 화성, 목성, 토성, 천왕성, 해왕성입니다. 그리고 이 외에도 왜왕성과 명왕성 등 왜행성으로 분류되는 몇몇 천체들이 존재합니다.',
#  '태양계에는 8개의 행성이 있습니다. 이들은 수성, 금성, 지구, 화성, 목성, 토성, 천왕성, 해왕성입니다. 플루토는 이전에 행성으로 분류되었지만, 지금은 소행성이나 왜 행성으로 분류됩니다.')
